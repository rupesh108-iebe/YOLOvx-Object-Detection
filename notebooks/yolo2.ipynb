# %%
# !pip install ultralytics --quiet
from IPython.display import clear_output
clear_output()
print("✅ YOLOv8 installed!")
# Out:
# ✅ YOLOv8 installed!

# %%
from google.colab import files
uploaded = files.upload()  # Upload your zip file
# Out:
#      <input type="file" id="files-0197f7ba-65f1-4325-ab04-16716849908c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0197f7ba-65f1-4325-ab04-16716849908c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile
import os

zip_path = next(iter(uploaded))
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall("/content/dataset")

print("✅ Dataset extracted")
# Out:
# ✅ Dataset extracted

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")  # You can use 'yolov8s.pt' for better accuracy

results = model.train(
    data="/content/dataset/data.yaml",
    epochs=4,
    imgsz=640,
    batch=8
)
# Out:
# Ultralytics 8.3.140 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# ...

# %%
from google.colab import files  # ✅ Import this first
uploaded = files.upload()  # 📥 Upload a video file (e.g., car.mp4)
video_path = next(iter(uploaded))
# Out:
#      <input type="file" id="files-5346f49a-110e-40f6-b3d7-622bb237330f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5346f49a-110e-40f6-b3d7-622bb237330f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from ultralytics import YOLO  # Import the Ultralytics YOLOv8 library

model = YOLO("yolov8n.pt")  # Load the YOLOv8 Nano model (or use yolov8s.pt, yolov8m.pt etc.)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-464527ba1d3a> in <cell line: 0>()
# ----> 1 from ultralytics import YOLO  # Import the Ultralytics YOLOv8 library
#       2
#       3 model = YOLO("yolov8n.pt")  # Load the YOLOv8 Nano model (or use yolov8s.pt, yolov8m.pt etc.)
#
# ModuleNotFoundError: No module named 'ultralytics'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from IPython.display import Image, display
import os

# Get the latest prediction directory
base_dir = "runs/detect"
latest_dir = sorted(os.listdir(base_dir))[-1]
output_dir = os.path.join(base_dir, latest_dir)

# Find first image in the directory and display it
image_files = [f for f in os.listdir(output_dir) if f.endswith(('.jpg', '.png'))]
if image_files:
    output_image = os.path.join(output_dir, image_files[0])
    display(Image(filename=output_image))
else:
    print("No image found in the latest prediction folder.")
